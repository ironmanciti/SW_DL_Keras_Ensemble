# %% [markdown]
# # Deep Learning 을 이용한 Red/White Wine 예측 - 이진 분류
#
# - Dataset 내용
#
#     - 고정산 (Fixed Acidity) : 포도의 산은 휘발산 / 비휘발(고정)산 두가지 종류가 있음. 단위 : gm/dm3
#     - 휘발산 (Volatile Acitidy) : 공기와 접촉하면 초산으로 변화. 단위 - gm/dm3
#     - 구연산 (Citric Acid) : 고정산의 일종. 단위 - g/dm3
#     - 잔당 (Residual Sugar) : 자연발효 후 남은 당분. 단위 - g/dm3
#     - 염화물 (Chloride) : 와인의 짠맛. 단위 - gm/dm3
#     - 이산화황 (Free sulfur dioxide) : 와인에 첨가한 이산화황 중 화홥물 형태가 아닌 것. 단위 - gm/dm3
#     - 총 이산화황 (Total Sulfur Dioxide) : 이산화황 총량. 단위 - gm/dm3
#     - 밀도 (density) : 알콜 농축도. 일반적으로 sweet 할 수록 density 가 높음
#     - pH : 7 미만 - 산성, 7 이상 - 알칼리성
#     - quality (score between 0 and 10)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# White Wine, Red Wine Dataset

# %%
white = pd.read_csv("datasets/winequality-white.csv", sep=";")
red = pd.read_csv("datasets/winequality-red.csv", sep=";")

# %%
red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# 3      9.9        6
# 4      9.9        6

# %% [markdown]
# ## Red 와 White wine의 Alchol 성분의 분포 시각화

# %%
fig, ax = plt.subplots(1, 2)

ax[0].hist(red.alcohol, 10, facecolor='red', alpha=0.5, label='red wine')
ax[0].legend()
ax[0].set_ylim([0, 1000])
ax[0].set_xlabel('alcohol in % vol')
ax[0].set_ylabel('frequency')

ax[1].hist(white.alcohol, 10, facecolor='white', ec='black', alpha=0.5, label='white wine')
ax[1].legend()
ax[1].yaxis.tick_right()
ax[1].set_xlabel('alcohol in % vol')
ax[1].set_ylabel('frequency')

plt.suptitle('Distribution of Alcohol in % Vol')
# Out:
# Text(0.5, 0.98, 'Distribution of Alcohol in % Vol')

# %% [markdown]
# Red + White wine .을 하나의 dataframe으로 합병

# %%
wine = pd.concat([red, white], ignore_index=True)
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# 데이터프레임의 모든 숫자형 열 사이의 상관계수를 계산합니다. corr() method는 피어슨 상관계수를 반환.

# %%
import seaborn as sns

correlation = wine.corr()
plt.figure(figsize=(14, 12))
sns.heatmap(correlation, annot=True);

# %% [markdown]
# quality 와 가장 양의 상관 관계가 높은 것은 alcohol 이고 density 와 chlorides 는 음의 상관관계가 있음.
#
# 사람들은 알콜 돗수가 높을 수록 고품질로 판단.

# %% [markdown]
# # Machine Learning - 이진 분류
#
# ## label column 추가
#
# - red wine - 1, white wine - 0

# %%
red['type'] = 1
white['type'] = 0

# %% [markdown]
# ## dataset 합치기

# %%
wine = red.copy()
wine = pd.concat([white, red], ignore_index=True)
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  type
# 0      8.8        6     0
# 1      9.5        6     0
# 2     10.1        6     0
# 3      9.9        6     0
# 4      9.9        6     0

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(wine.iloc[:, 0:11], wine.iloc[:, 12], random_state=45)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((4872, 11), (1625, 11), (4872,), (1625,))

# %% [markdown]
# ## Build model

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(50, input_shape=(11,), activation='relu'))
model.add(Dense(30, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                600
#
#  dense_1 (Dense)             (None, 30)                1530
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 2,161
# Trainable params: 2,161
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=20, batch_size=32, verbose=1)
# Out:
# Epoch 1/20
# 153/153 [==============================] - 1s 728us/step - loss: 0.5316 - accuracy: 0.8748
# Epoch 2/20
# 153/153 [==============================] - 0s 708us/step - loss: 0.1936 - accuracy: 0.9321
# Epoch 3/20
# 153/153 [==============================] - 0s 701us/step - loss: 0.1816 - accuracy: 0.9358
# Epoch 4/20
# 153/153 [==============================] - 0s 710us/step - loss: 0.1698 - accuracy: 0.9397
# Epoch 5/20
# 153/153 [==============================] - 0s 716us/step - loss: 0.1602 - accuracy: 0.9423
# Epoch 6/20
# 153/153 [==============================] - 0s 679us/step - loss: 0.1491 - accuracy: 0.9497
# Epoch 7/20
# 153/153 [==============================] - 0s 694us/step - loss: 0.1380 - accuracy: 0.9522
# Epoch 8/20
# 153/153 [==============================] - 0s 677us/step - loss: 0.1331 - accuracy: 0.9546
# Epoch 9/20
# 153/153 [==============================] - 0s 668us/step - loss: 0.1215 - accuracy: 0.9589
# Epoch 10/20
# 153/153 [==============================] - 0s 671us/step - loss: 0.1222 - accuracy: 0.9608
# Epoch 11/20
# 153/153 [==============================] - 0s 725us/step - loss: 0.1147 - accuracy: 0.9643
# Epoch 12/20
# 153/153 [==============================] - 0s 669us/step - loss: 0.1037 - accuracy: 0.9655
# Epoch 13/20
# 153/153 [==============================] - 0s 683us/step - loss: 0.1080 - accuracy: 0.9661
# Epoch 14/20
# 153/153 [==============================] - 0s 664us/step - loss: 0.0937 - accuracy: 0.9709
# Epoch 15/20
# 153/153 [==============================] - 0s 663us/step - loss: 0.0911 - accuracy: 0.9721
# Epoch 16/20
# 153/153 [==============================] - 0s 689us/step - loss: 0.0931 - accuracy: 0.9692
# Epoch 17/20
# 153/153 [==============================] - 0s 657us/step - loss: 0.0920 - accuracy: 0.9737
# Epoch 18/20
# 153/153 [==============================] - 0s 673us/step - loss: 0.0844 - accuracy: 0.9737
# Epoch 19/20
# 153/153 [==============================] - 0s 675us/step - loss: 0.0810 - accuracy: 0.9752
# Epoch 20/20
# 153/153 [==============================] - 0s 669us/step - loss: 0.0787 - accuracy: 0.9774

# %%
y_pred = model.predict(X_test) > 0.5
# Out:
# 51/51 [==============================] - 0s 536us/step

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
confusion_matrix(y_test, y_pred, labels=[1,0])
# Out:
# array([[ 392,   28],
#        [   8, 1197]], dtype=int64)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9778461538461538

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      1205
#            1       0.98      0.93      0.96       420
#
#     accuracy                           0.98      1625
#    macro avg       0.98      0.96      0.97      1625
# weighted avg       0.98      0.98      0.98      1625
